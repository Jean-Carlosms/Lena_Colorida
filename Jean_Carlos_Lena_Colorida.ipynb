# %% [markdown]
# <a href="https://colab.research.google.com/github/Jean-Carlosms/Lena_Colorida/blob/main/Jean_Carlos_Lena_Colorida.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Biblioteca
import cv2
from google.colab.patches import cv2_imshow

# %%
# !git clone https://github.com//Jean-Carlosms/Lena_Colorida
# !ls Lena_Colorida
# Out:
# fatal: destination path 'Lena_Colorida' already exists and is not an empty directory.
# lenna.jpg

# %%
imagem = cv2.imread('/content/Lena_Colorida/lenna.jpg')
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
imagem = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)
cv2_imshow(imagem)
# Out:
# <PIL.Image.Image image mode=L size=512x512>

# %%
limiar = 130
valor, lim_simples = cv2.threshold(imagem, limiar, 255, cv2.THRESH_BINARY)
cv2_imshow(lim_simples)
# Out:
# <PIL.Image.Image image mode=L size=512x512>
